# %%
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.mplot3d import Axes3D

# %%
vectors = np.array([[70, 110, 500], [-0.4913, -0.7651, -0.4161],
                   [1,0,0], [0,1,0], [0,0,1]])
e1, omega, i, j, k = zip(vectors)
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.quiver(e1, omega)
# ax.set_xlim([-1, 0.5])
# ax.set_ylim([-1, 1.5])
# ax.set_zlim([-1, 8])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 6
#       4 fig = plt.figure()
#       5 ax = fig.add_subplot(111, projection='3d')
# ----> 6 ax.quiver(e1, omega)
#       7 # ax.set_xlim([-1, 0.5])
#       8 # ax.set_ylim([-1, 1.5])
#       9 # ax.set_zlim([-1, 8])
#      10 plt.show()
#
# File /opt/anaconda3/lib/python3.13/site-packages/matplotlib/__init__.py:1521, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1518 @functools.wraps(func)
#    1519 def inner(ax, *args, data=None, **kwargs):
#    1520     if data is None:
# -> 1521         return func(
#    1522             ax,
#    1523             *map(cbook.sanitize_sequence, args),
#    1524             **{k: cbook.sanitize_sequence(v) for k, v in kwargs.items()})
#    1526     bound = new_sig.bind(ax, *args, **kwargs)
#    1527     auto_label = (bound.arguments.get(label_namer)
# ...
